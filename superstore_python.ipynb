# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\priya\OneDrive\Desktop\capstone1\superstore_clean.csv")

# %%
df.head()
# Out:
#               Order_ID  Order_Date   Ship_Date         Category  \
# Row_ID
# 1       CA-2017-152156  08-11-2017  11-11-2017        Furniture
# 2       CA-2017-152156  08-11-2017  11-11-2017        Furniture
# 3       CA-2017-138688  12-06-2017  16-06-2017  Office Supplies
# 4       US-2016-108966  11-10-2016  18-10-2016        Furniture
# 5       US-2016-108966  11-10-2016  18-10-2016  Office Supplies
#
#                    City        Country Customer_ID    Customer_Name  \
# Row_ID
# 1             Henderson  United States    CG-12520      Claire Gute
# 2             Henderson  United States    CG-12520      Claire Gute
# 3           Los Angeles  United States    DV-13045  Darrin Van Huff
# 4       Fort Lauderdale  United States    SO-20335   Sean O'Donnell
# 5       Fort Lauderdale  United States    SO-20335   Sean O'Donnell
#
#        Delivery_Pace  Delivery_Time  ... Postal_Code       Product_ID  \
# Row_ID                               ...
# ...

# %%
df=df.set_index('Row_ID')

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Ship_Date', 'Category', 'City', 'Country',
#        'Customer_ID', 'Customer_Name', 'Delivery_Pace', 'Delivery_Time',
#        'Month_Name', 'Postal_Code', 'Product_ID', 'Product_Name', 'Region',
#        'Sales', 'Segment', 'Ship_Mode', 'State', 'Sub_Category', 'Year'],
#       dtype='object')

# %%
df.shape
# Out:
# (9800, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9800 entries, 1 to 9800
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       9800 non-null   object
#  1   Order_Date     9800 non-null   object
#  2   Ship_Date      9800 non-null   object
#  3   Category       9800 non-null   object
#  4   City           9800 non-null   object
#  5   Country        9800 non-null   object
#  6   Customer_ID    9800 non-null   object
#  7   Customer_Name  9800 non-null   object
#  8   Delivery_Pace  9800 non-null   object
#  9   Delivery_Time  9800 non-null   int64
#  10  Month_Name     9800 non-null   object
#  11  Postal_Code    9789 non-null   float64
#  12  Product_ID     9800 non-null   object
#  13  Product_Name   9800 non-null   object
#  14  Region         9800 non-null   object
#  15  Sales          9800 non-null   float64
#  16  Segment        9800 non-null   object
# ...

# %%
df.describe()
# Out:
#        Delivery_Time   Postal_Code         Sales         Year
# count    9800.000000   9789.000000   9800.000000  9800.000000
# mean        3.961122  55273.322403    230.769059  2016.724184
# std         1.749614  32041.223413    626.651875     1.123984
# min         0.000000   1040.000000      0.444000  2015.000000
# 25%         3.000000  23223.000000     17.248000  2016.000000
# 50%         4.000000  58103.000000     54.490000  2017.000000
# 75%         5.000000  90008.000000    210.605000  2018.000000
# max         7.000000  99301.000000  22638.480000  2018.000000

# %%
month_order = [
    'January','February','March','April','May','June',
    'July','August','September','October','November','December'
]

df['Month_Name'] = pd.Categorical(
    df['Month_Name'],
    categories=month_order,
    ordered=True
)

df.groupby('Month_Name')['Sales'].sum().plot()
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_10316\2397211472.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Month_Name')['Sales'].sum().plot()
# <Axes: xlabel='Month_Name'>

# %%
df.groupby('Product_Name')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Product_Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
df['Sales'].hist(bins=50)
plt.xlabel('Sales amount')
plt.ylabel('Number of Observations')
plt.title('Sales Distribution')
# Out:
# Text(0.5, 1.0, 'Sales Distribution')
